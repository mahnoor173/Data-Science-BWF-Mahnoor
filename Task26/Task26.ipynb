# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
class DiabetesModel(tf.keras.Model):
    def __init__(self):
        super(DiabetesModel, self).__init__()
        self.dense1 = keras.layers.Dense(64, activation='relu')
        self.dense2 = keras.layers.Dense(32, activation='relu')
        self.dense3 = keras.layers.Dense(1, activation='sigmoid')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.dense3(x)

# Example data (glucose level, blood pressure, BMI)
X_train = np.random.rand(100, 3)
y_train = np.random.randint(0, 2, 100)  # Binary labels: 0 (non-diabetic) or 1 (diabetic)

# Create and compile the model
model = DiabetesModel()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=10, verbose=1)  # Verbose=1 prints training progress

# Evaluate the model on some test data
# Using same data for simplicity; ideally, use separate test data
loss, accuracy = model.evaluate(X_train, y_train, verbose=1)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")

# Display training history
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4970 - loss: 0.6927
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5099 - loss: 0.6927
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5224 - loss: 0.6912
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4832 - loss: 0.6935
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5123 - loss: 0.6893
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5519 - loss: 0.6839
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5175 - loss: 0.6869
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5415 - loss: 0.6837
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4905 - loss: 0.6953
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5238 - loss: 0.6868
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5050 - loss: 0.6903
# Test Loss: 0.6887586712837219
# ...
